# %%
import pandas as pd
# De praxe, carregamos o arquivo csv usando panda e definimos inicialmente o dataframe como df
df = pd.read_csv('SICOR_CONTRATOS_MUNICIPIO_2020_BRUTO.csv', header=0, engine='python', on_bad_lines='skip')

# %%
# Aqui nos apenas estamos filtrando o dataframe para aparecer somente os dados do estado do ceara, assim descartando os demais por não ser no nosso interesse
df_CE = df[df['nomeUF'] == 'CE']
print(df_CE.iloc[0:10])  # Exibe as linhas de 1 a 9 do dataframe filtrado para o estado do Ceará
# Out:
#      #cdEstado nomeUF  cdMunicipio  codMunicIbge            Municipio  MesEmissao  AnoEmissao  cdPrograma  cdSubPrograma  cdFonteRecurso  Atividade  QtdCusteio  VlCusteio  QtdInvestimento  VlInvestimento  QtdComercializacao  VlComercializacao  QtdIndustrializacao  VlIndustrializacao  AreaInvestimento  AreaCusteio    cnpjIF                          nomeIF
# 390          6     CE        33486     2312304.0         S�O BENEDITO          10        2020           1              2             300          1           0        0.0                1        14500.00                   0                0.0                    0                 0.0              0.30          0.0         0              BCO DO BRASIL S.A.
# 402          6     CE        44901     2308377.0              MIRA�MA          11        2020           1             56             502          1          14    49000.0                3        10000.00                   0                0.0                    0                 0.0              0.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 444          6     CE        19929     2309904.0               PACUJ�           9        2020           1             56             502          2           0        0.0               11        36500.00                   0                0.0                    0                 0.0              0.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 456          6     CE        34863     2304400.0            FORTALEZA          10        2020         999              0             201          1           0        0.0                0            0.00                   0                0.0                    1           1500000.0              0.00          0.0  60701190                   BCO ITAU S.A.
# 671          6     CE        10894     2307700.0           MARANGUAPE           4        2020         999              0             201          2           0        0.0                0            0.00                   0                0.0                    2           2000000.0              0.00          0.0  90400888   BCO MERIDIONAL DO BRASIL S.A.
# 766          6     CE        11594     2302305.0            BELA CRUZ          12        2020           1             56             502          2           0        0.0                8        19070.00                   0                0.0                    0                 0.0              3.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 891          6     CE        24653     2305407.0                  IC�           1        2020           1              2             502          1           0        0.0                1         4233.00                   0                0.0                    0                 0.0              0.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 918          6     CE        43407     2304277.0                ERER�           9        2020           1              5             502          1           0        0.0                3        27695.18                   0                0.0                    0                 0.0              1.11          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 951          6     CE        18425     2305001.0  GUARACIABA DO NORTE           4        2020           1             56             502          2           0        0.0               10        47500.00                   0                0.0                    0                 0.0              0.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
# 979          6     CE        11006     2310209.0             PARACURU           2        2020         999              0             502          1           0        0.0                1       117000.00                   0                0.0                    0                 0.0              0.00          0.0   7237373  BCO DO NORDESTE DO BRASIL S.A.
